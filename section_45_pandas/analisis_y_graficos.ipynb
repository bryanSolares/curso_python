# %%
import pandas as pd
import cufflinks as cf
from IPython.display import display, HTML

cf.set_config_file(sharing='public', theme='space', offline=True)
cf.getThemes()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_36536\2484447471.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
# ...

# %%
data = pd.read_csv("./Referencia/pais.csv")
data
# Out:
#                Pais    Year     Poblacion
# 0             China  2020.0  1.439324e+09
# 1             China  2019.0  1.433784e+09
# 2             China  2018.0  1.427648e+09
# 3             China  2017.0  1.421022e+09
# 4             China  2016.0  1.414049e+09
# ...             ...     ...           ...
# 4180  United States  1965.0  1.997337e+08
# 4181  United States  1960.0  1.867206e+08
# 4182  United States  1955.0  1.716853e+08
# 4183          India  1960.0  4.505477e+08
# 4184          India  1955.0  4.098806e+08
#
# [4185 rows x 3 columns]

# %%
data = data.dropna()
data
# Out:
#                Pais    Year     Poblacion
# 0             China  2020.0  1.439324e+09
# 1             China  2019.0  1.433784e+09
# 2             China  2018.0  1.427648e+09
# 3             China  2017.0  1.421022e+09
# 4             China  2016.0  1.414049e+09
# ...             ...     ...           ...
# 4180  United States  1965.0  1.997337e+08
# 4181  United States  1960.0  1.867206e+08
# 4182  United States  1955.0  1.716853e+08
# 4183          India  1960.0  4.505477e+08
# 4184          India  1955.0  4.098806e+08
#
# [4178 rows x 3 columns]

# %%
# Pivotear una tabla
data = data.pivot(index='Year', columns='Pais', values='Poblacion')
data
# Out:
# Pais    Afghanistan    Albania     Algeria  American Samoa  Andorra  \
# Year
# 1955.0    8270991.0  1419994.0   9774283.0         19754.0   9232.0
# 1960.0    8996973.0  1636090.0  11057863.0         20123.0  13411.0
# 1965.0    9956320.0  1896171.0  12550885.0         23672.0  18549.0
# 1970.0   11173642.0  2150707.0  14464985.0         27363.0  24276.0
# 1975.0   12689160.0  2411732.0  16607707.0         30052.0  30705.0
# 1980.0   13356511.0  2682690.0  19221665.0         32646.0  36067.0
# 1985.0   11938208.0  2969672.0  22431502.0         39519.0  44600.0
# 1990.0   12412308.0  3286073.0  25758869.0         47347.0  54509.0
# 1995.0   18110657.0  3112936.0  28757785.0         53161.0  63850.0
# 2000.0   20779953.0  3129243.0  31042235.0         57821.0  65390.0
# 2005.0   25654277.0  3086810.0  33149724.0         59562.0  78867.0
# 2010.0   29185507.0  2948023.0  35977455.0         56079.0  84449.0
# 2015.0   34413603.0  2890513.0  39728025.0         55812.0  78011.0
# ...

# %%
# Gráfico de líneas
data[['Albania','Algeria','India', 'China']].iplot(kind="line", xTitle="Year", yTitle="Population", title="Gráfico")

# %%
# Gráfico de barras
data[['Albania','Algeria','India', 'China']].iplot(kind="bar", xTitle="Year", yTitle="Population", title="Gráfico")

# %%
data[data.index.isin([1990])][['Albania','Algeria','India', 'China', "Brazil", "United States"]].iplot(kind="bar", xTitle="Year", yTitle="Population", title="Gráfico")

# %%
# Modificando el orden de los gráficos
data[data.index.isin([2018,2019,2020])][['Albania','Algeria','India', 'China', "Brazil", "United States"]].T.iplot(kind="bar", xTitle="Year", yTitle="Population", title="Gráfico")

# %%
# Nuevo tipo de gráfico TIPO CAJA
data[['Albania','Algeria','India', 'China', "Brazil", "United States"]].iplot(kind="box")

# %%
# Nuevo tipo de gráfico TIPO HISTOGRAMA
data[['Albania','Algeria','India', 'China', "Brazil", "United States"]].iplot(kind="hist")

# %%
# Nuevo tipo de gráfico TIPO PASTEL
data2020 = data[data.index.isin([2020])][['Albania','Algeria','India', 'China', "Brazil", "United States"]].T

data2020 = data2020.rename(columns={2020:"2020"})

data2020.reset_index().iplot(kind="pie", labels="Pais", values="2020")

# %%
data[['Albania','Algeria','India', 'China', "Brazil", "United States"]].iplot(kind="scatter", mode="markers", xTitle="Año", yTitle="Población", title="Año vs Población")
