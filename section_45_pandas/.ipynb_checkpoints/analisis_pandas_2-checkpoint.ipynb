# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('./Referencia/base_2.csv')
data.head(10)
# Out:
#    id      Nombre  Apellidos                         Email       Gender  \
# 0   1  Hildegaard      Epple             hepple0@adobe.com       Female
# 1   2      Yettie      Kelle             ykelle1@cisco.com   Polygender
# 2   3      Elijah     Kidson            ekidson2@sogou.com         Male
# 3   4   Francisca  Lodovichi         flodovichi3@opera.com       Female
# 4   5   Georgiana   Luxmoore          gluxmoore4@salon.com          NaN
# 5   6   Meredithe     Heinle              mheinle5@nih.gov       Female
# 6   7         Cam     Melato  cmelato6@acquirethisname.com         Male
# 7   8  Margaretta  de Voiels    mdevoiels7@cyberchimps.com       Female
# 8   9         NaN     Julian              njulian8@ibm.com  Genderfluid
# 9  10        Niko    Ferencz      nferencz9@vistaprint.com         Male
#
#           Direccion  Edad             Carrera Sueldo      Idioma
# 0               NaN     1           Marketing  $2.43  Belarusian
# ...

# %%
# Indexado de información
data = pd.read_csv('./Referencia/base_2.csv', index_col="id")
data
# Out:
#           Nombre   Apellidos                         Email      Gender  \
# id
# 1     Hildegaard       Epple             hepple0@adobe.com      Female
# 2         Yettie       Kelle             ykelle1@cisco.com  Polygender
# 3         Elijah      Kidson            ekidson2@sogou.com        Male
# 4      Francisca   Lodovichi         flodovichi3@opera.com      Female
# 5      Georgiana    Luxmoore          gluxmoore4@salon.com         NaN
# ...          ...         ...                           ...         ...
# 996      Josepha     Raeside      jraesidern@sitemeter.com      Female
# 997       Joella  O'Hagirtie  johagirtiero@dailymail.co.uk      Female
# 998       Dahlia   Thackwray  dthackwrayrp@theatlantic.com      Female
# 999    Marie-ann     Drewett  mdrewettrq@independent.co.uk      Female
# 1000       Nelli      Braven          nbravenrr@boston.com      Female
#
#           Direccion  Edad             Carrera Sueldo      Idioma
# id
# ...

# %%
# Limpiando valores en nulo
data.dropna()
# Out:
#          Nombre   Apellidos                         Email      Gender  \
# id
# 2        Yettie       Kelle             ykelle1@cisco.com  Polygender
# 3        Elijah      Kidson            ekidson2@sogou.com        Male
# 7           Cam      Melato  cmelato6@acquirethisname.com        Male
# 8    Margaretta   de Voiels    mdevoiels7@cyberchimps.com      Female
# 10         Niko     Ferencz      nferencz9@vistaprint.com        Male
# ..          ...         ...                           ...         ...
# 995       Barry     Bownass          bbownassrm@google.cn        Male
# 996     Josepha     Raeside      jraesidern@sitemeter.com      Female
# 997      Joella  O'Hagirtie  johagirtiero@dailymail.co.uk      Female
# 998      Dahlia   Thackwray  dthackwrayrp@theatlantic.com      Female
# 999   Marie-ann     Drewett  mdrewettrq@independent.co.uk      Female
#
#             Direccion  Edad               Carrera Sueldo     Idioma
# id
# ...

# %%
# Predefinir un valor a los valores que son nulos de manera general
data.fillna(0)
# Out:
#           Nombre   Apellidos                         Email      Gender  \
# id
# 1     Hildegaard       Epple             hepple0@adobe.com      Female
# 2         Yettie       Kelle             ykelle1@cisco.com  Polygender
# 3         Elijah      Kidson            ekidson2@sogou.com        Male
# 4      Francisca   Lodovichi         flodovichi3@opera.com      Female
# 5      Georgiana    Luxmoore          gluxmoore4@salon.com           0
# ...          ...         ...                           ...         ...
# 996      Josepha     Raeside      jraesidern@sitemeter.com      Female
# 997       Joella  O'Hagirtie  johagirtiero@dailymail.co.uk      Female
# 998       Dahlia   Thackwray  dthackwrayrp@theatlantic.com      Female
# 999    Marie-ann     Drewett  mdrewettrq@independent.co.uk      Female
# 1000       Nelli      Braven          nbravenrr@boston.com      Female
#
#           Direccion  Edad             Carrera Sueldo      Idioma
# id
# ...

# %%
# Predefinir un valor a ciertas columnas según escenario
data.fillna({"Direccion":"Sin dirección", "Idioma": "Indeterminado", "Gender": "Pendiente"})
# Out:
#           Nombre   Apellidos                         Email      Gender  \
# id
# 1     Hildegaard       Epple             hepple0@adobe.com      Female
# 2         Yettie       Kelle             ykelle1@cisco.com  Polygender
# 3         Elijah      Kidson            ekidson2@sogou.com        Male
# 4      Francisca   Lodovichi         flodovichi3@opera.com      Female
# 5      Georgiana    Luxmoore          gluxmoore4@salon.com   Pendiente
# ...          ...         ...                           ...         ...
# 996      Josepha     Raeside      jraesidern@sitemeter.com      Female
# 997       Joella  O'Hagirtie  johagirtiero@dailymail.co.uk      Female
# 998       Dahlia   Thackwray  dthackwrayrp@theatlantic.com      Female
# 999    Marie-ann     Drewett  mdrewettrq@independent.co.uk      Female
# 1000       Nelli      Braven          nbravenrr@boston.com      Female
#
#           Direccion  Edad             Carrera Sueldo         Idioma
# id
# ...

# %%
# Filtrado por columnas
data[["Nombre", "Apellidos"]]
# Out:
#           Nombre   Apellidos
# id
# 1     Hildegaard       Epple
# 2         Yettie       Kelle
# 3         Elijah      Kidson
# 4      Francisca   Lodovichi
# 5      Georgiana    Luxmoore
# ...          ...         ...
# 996      Josepha     Raeside
# 997       Joella  O'Hagirtie
# 998       Dahlia   Thackwray
# 999    Marie-ann     Drewett
# 1000       Nelli      Braven
#
# [1000 rows x 2 columns]

# %%
# Filtrado por Filas
data.iloc[:5]
# Out:
#         Nombre  Apellidos                  Email      Gender    Direccion  \
# id
# 1   Hildegaard      Epple      hepple0@adobe.com      Female          NaN
# 2       Yettie      Kelle      ykelle1@cisco.com  Polygender        Corse
# 3       Elijah     Kidson     ekidson2@sogou.com        Male         Oslo
# 4    Francisca  Lodovichi  flodovichi3@opera.com      Female  Direccion 2
# 5    Georgiana   Luxmoore   gluxmoore4@salon.com         NaN  Direccion 3
#
#     Edad             Carrera Sueldo      Idioma
# id
# 1      1           Marketing  $2.43  Belarusian
# 2      2          Accounting  $8.62       Tamil
# 3      3               Legal  $3.88     Swahili
# 4      4  Product Management  $0.58         NaN
# 5      5     Human Resources  $9.91       Czech

# %%
# Filtros combinados por columna y fila
data.loc[[1,5,9,12,34],["Nombre", "Apellidos"]]
# Out:
#         Nombre  Apellidos
# id
# 1   Hildegaard      Epple
# 5    Georgiana   Luxmoore
# 9          NaN     Julian
# 12     Giacobo    McMyler
# 34        Elva  Duchateau

# %%
# Considera que los nombres de las columnas con KeySensitive
data[data["Gender"]=="Male"]
# Out:
#        Nombre  Apellidos                         Email Gender  \
# id
# 3      Elijah     Kidson            ekidson2@sogou.com   Male
# 7         Cam     Melato  cmelato6@acquirethisname.com   Male
# 10       Niko    Ferencz      nferencz9@vistaprint.com   Male
# 11   Lowrance  Francioli                           NaN   Male
# 16    Carling      Fabri             cfabrif@sogou.com   Male
# ..        ...        ...                           ...    ...
# 986    Yehudi     Wolfit         ywolfitrd@spotify.com   Male
# 987    Emmett      Drake           edrakere@tumblr.com   Male
# 989    Hector    Mucillo           hmucillorg@ebay.com   Male
# 994      Vern     Dibner         vdibnerrl@storify.com   Male
# 995     Barry    Bownass          bbownassrm@google.cn   Male
#
#             Direccion  Edad               Carrera Sueldo       Idioma
# id
# 3                Oslo     3                 Legal  $3.88      Swahili
# 7    Viana do Castelo     7                 Legal  $4.24        Swati
# ...
